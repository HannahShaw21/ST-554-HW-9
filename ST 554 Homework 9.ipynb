# %% [markdown]
# # ST 554 Homework 9
#
# ### By Hannah Shaw

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Splitting the Data, Metrics, and Models

# %% [markdown]
# ## Model Fitting

# %% [markdown]
# ## Model Testing

# %%
## Sleepy. Finish later
