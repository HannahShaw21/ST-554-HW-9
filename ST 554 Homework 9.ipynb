# %% [markdown]
# # ST 554 Homework 9
#
# ### By Hannah Shaw

# %% [markdown]
# ## Introduction
#
# In this homework assignment, we will fit supervised learning models that have not yet been used in previous homeworks onto the Oxford Parkinson's Disease Telemonitoring Dataset (source: https://www.kaggle.com/datasets/porinitahoque/parkinsons-telemonitoring/data). Using a numeric or binary response, we will fit three different classes of models onto the data and choose an overall best model based on the results. We will be using `pyspark` for the purposes of this assignment.
#
# First, we read in the Parkinson's dataset.

# %%
from pyspark.sql import DataFrame
from pyspark.sql import functions as F
from functools import reduce
from pyspark.sql.types import *
import numpy as np
import pandas as pd

#read in the Parkinson's dataset
Parkinsons = pd.read_csv("Parkinsons-Telemonitoring-ucirvine.csv")
Parkinsons.head()
# Out:
#    subject  age    sex  test_time  motor_updrs  total_updrs   jitter  \
# 0        1   72  False     5.6431       28.199       34.398  0.00662
# 1        1   72  False    12.6660       28.447       34.894  0.00300
# 2        1   72  False    19.6810       28.695       35.389  0.00481
# 3        1   72  False    25.6470       28.905       35.810  0.00528
# 4        1   72  False    33.6420       29.187       36.375  0.00335
#
#    jitter_abs  jitter_rap  jitter_ppq5  ...  shimmer_db  shimmer_apq3  \
# 0    0.000034     0.00401      0.00317  ...       0.230       0.01438
# 1    0.000017     0.00132      0.00150  ...       0.179       0.00994
# 2    0.000025     0.00205      0.00208  ...       0.181       0.00734
# 3    0.000027     0.00191      0.00264  ...       0.327       0.01106
# 4    0.000020     0.00093      0.00130  ...       0.176       0.00679
#
#    shimmer_apq5  shimmer_apq11  shimmer_dda       nhr     hnr     rpde  \
# ...

# %% [markdown]
# ## Splitting the Data, Metrics, and Models
#
# For the purposes of this assignment, we will be looking at `total_UPDRS` as a function of the other variables in the dataset. First, we will use spark MLlib to split the data into a training and test set.

# %% [markdown]
# ## Model Fitting

# %% [markdown]
# ## Model Testing

# %%
## Sleepy. Finish later
